# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import json


with open('GameInformer.json') as f:
    data = json.load(f)
jogos = pd.DataFrame(data)
jogos
# Out:
#                                           titulo  nota  \
# 0                                      Unsighted     9
# 1                             Resident Evil 4 VR  8.75
# 2    The Dark Pictures Anthology: House of Ashes   7.5
# 3                                    Inscryption     9
# 4               Marvel's Guardians of the Galaxy   8.5
# ..                                           ...   ...
# 924                                    Videoball  6.75
# 925                                        Bound  7.75
# 926                     Deus Ex: Mankind Divided     7
# 927               Metroid Prime Federation Force     7
# 928                               Alone With You     7
#
#                        publisher               desenvolvedora  \
# 0                   Humble Games                 Studio Pixel
# 1                         Capcom              Armature Studio
# 2                   Bandai Namco           Supermassive Games
# 3               Devolver Digital         Daniel Mullins Games
# 4                    Square Enix               Eidos Montreal
# ..                           ...                          ...
# 924          Iron Galaxy Studios  Action Button Entertainment
# 925  Sony Computer Entertainment                      Plastic
# 926                  Square Enix               Eidos Montreal
# 927                     Nintendo             Next Level Games
# 928              Benjamin Rivers              Benjamin Rivers
#
#              lancamento
# 0    September 30, 2021
# 1      October 21, 2021
# 2      October 21, 2021
# 3      October 19, 2021
# 4      October 26, 2021
# ..                  ...
# 924       July 12, 2016
# 925     August 16, 2016
# 926     August 23, 2016
# 927     August 19, 2016
# 928                None
#
# [929 rows x 5 columns]

# %%
faixas = np.arange(0,10,0.3)
nota = jogos['nota']
notas = []
for i in nota:
    a=float(i)
    notas.append(a)
    
publisher = jogos['publisher']
plt.hist(notas, bins=faixas, edgecolor='white')
# Out:
# (array([  0.,   0.,   0.,   0.,   0.,   0.,   5.,   0.,   0.,   0.,   1.,
#           1.,   1.,   5.,   0.,   4.,  20.,   0.,  11.,   5.,  57.,  35.,
#          22.,  83.,  40., 148., 133.,  57.,  97.,  64., 112.,  20.,   5.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. , 3.3, 3.6,
#         3.9, 4.2, 4.5, 4.8, 5.1, 5.4, 5.7, 6. , 6.3, 6.6, 6.9, 7.2, 7.5,
#         7.8, 8.1, 8.4, 8.7, 9. , 9.3, 9.6, 9.9]),
#  <BarContainer object of 33 artists>)

# %%
nintendo = jogos[jogos["publisher"]=='Nintendo']
nintendo
# Out:
#                                        titulo  nota publisher  \
# 12                     Mario Party Superstars     8  Nintendo
# 24                WarioWare: Get It Together!  7.75  Nintendo
# 37                              Metroid Dread     9  Nintendo
# 65   Famicom Detective Club: The Missing Heir  7.25  Nintendo
# 70                     Mario Golf: Super Rush  8.25  Nintendo
# ..                                        ...   ...       ...
# 876        Super Mario Maker For Nintendo 3DS  7.75  Nintendo
# 885                 Paper Mario: Color Splash  8.25  Nintendo
# 915                        Picross 3D Round 2  8.75  Nintendo
# 918              Yo-kai Watch 2: Fleshy Souls     7  Nintendo
# 927            Metroid Prime Federation Force     7  Nintendo
#
#                     desenvolvedora          lancamento
# 12                        Nintendo    October 29, 2021
# 24   Intelligent Systems, Nintendo  September 10, 2021
# 37                    MercurySteam     October 8, 2021
# 65                           MAGES        May 14, 2021
# 70                Camelot Software       June 25, 2021
# ..                             ...                 ...
# 876                       Nintendo    December 2, 2016
# 885                       Nintendo     October 7, 2016
# 915                       Nintendo   September 1, 2016
# 918                        Level-5  September 30, 2016
# 927               Next Level Games     August 19, 2016
#
# [68 rows x 5 columns]

# %%
faixas = np.arange(0,10,0.3)
nota_n = nintendo['nota']

notas_n = []
for i in nota_n:
    a=float(i)
    notas_n.append(a)
    
publisher_n = nintendo['publisher']
plt.hist(notas_n, bins=faixas, edgecolor='white')
nota_10 = nintendo[nintendo["nota"]=='10']
nota_10
# Out:
#                                       titulo nota publisher desenvolvedora  \
# 828  The Legend of Zelda: Breath of the Wild   10  Nintendo       Nintendo
#
#         lancamento
# 828  March 3, 2017
